# %%
from echr import *
from nb_tfidf import *
from bert import *
import os
import re
from tqdm import tqdm
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import SGDClassifier
from csv import DictWriter
from tqdm import tqdm
from joblib import Parallel, delayed

# %load_ext autoreload
# %autoreload 2

# %%
med_path = 'datasets/Medvedeva/'
json_path = 'datasets/echrod/cases.json'
part = 'facts'
article = '6'
balance = True
year = 2018
method = 'only'
best_alpha = 5

# df_complete = create_dataset(med_path, article, part)
df_complete = create_dataset(json_path, article, part)

# %%
def run_experiment(df_complete, year, method, window=10, train_size=None):
    
    # Prepare the data
    df_train, df_test = split_db(df_complete, method, year, window=window, train_size=train_size)
    df_train = balance_dataset(df_train) 
    X_train = df_train['text'].to_numpy()
    y_train = df_train['violation'].to_numpy()
    X_test = df_test['text'].to_numpy()
    y_test = df_test['violation'].to_numpy()
    
    if len(y_test) > 0 and len(y_train) > 0:
        # Preprocess text
        X_train_preprocessed = np.array([text_preprocessing(text) for text in X_train])
        X_test_preprocessed = np.array([text_preprocessing(text) for text in X_test])

        # Calculate TF-IDF
        tf_idf = TfidfVectorizer(ngram_range=(1, 3),
                                 binary=True,
                                 smooth_idf=False)
        X_train_tfidf = tf_idf.fit_transform(X_train_preprocessed)
        X_test_tfidf = tf_idf.transform(X_test_preprocessed)

        # Train model
        nb_model = RandomForestClassifier(n_jobs=-1, bootstrap=False,  max_depth=100.0, max_features='auto',  min_samples_leaf=2,  min_samples_split=10,  n_estimators=2000)
        nb_model.fit(X_train_tfidf, y_train)

        # Test model
        preds = nb_model.predict(X_test_tfidf)
        acc, mcc, f1 = return_metrics(preds, y_test)
    else:
        acc, mcc, f1 = 0, 0, 0
    
    # Write the results to a csv file
    field_names = ['year', 'accuracy', 'MCC', 'F1',  'window', 'method', 
                   'training_size', 'test_size', 'train_distribution', 'test_distribution']
    dct = {
        'year': year,
        'accuracy': acc,
        'MCC': mcc,
        'F1': f1,
        'method': method,
        'window': window,
        'training_size': len(df_train),
        'test_size': len(df_test),
        'train_distribution': round(df_train['violation'].mean()*100,2),
        'test_distribution': round(df_test['violation'].mean()*100,2)
         }
    
    filename = 'results/RF/years/years_'+method+'.csv'
    file_exists = os.path.isfile(filename)
    with open(filename, 'a') as f_object:
        dictwriter_object = DictWriter(f_object, fieldnames=field_names)
        if not file_exists:
            dictwriter_object.writeheader()  # file doesn't exist yet, write a header
        dictwriter_object.writerow(dct)
        f_object.close()
    return 0

# %%
# Test set includes all cases during 'year'
all_results = Parallel(n_jobs=4)(delayed(run_experiment)(df_complete, year, method='only') for year in tqdm(range(1978, 2023)))

# %%
# Test set includes all cases during 'year' and train on random samples of a given size
results = pd.read_csv('results/SVM/years/years_only.csv')
train_sizes = dict(zip(results['year'], results['training_size']))
all_results = Parallel(n_jobs=4)(delayed(run_experiment)(df_complete, year, method='random', train_size=train_sizes[year]) for year in tqdm(range(1978, 2023)))
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 45/45 [04:58<00:00,  6.63s/it]

# %%
# # Using sliding window of X past years
all_results = Parallel(n_jobs=1)(delayed(run_experiment)(df_complete, year, method='window', window=window) 
                                  for window in range(5, 60, 5) 
#                                   for window in range(25, 60, 5) 
                                  for year in tqdm(range(1978, 2023)))

# %% [markdown]
# #### Analyze results

# %%
only_results = pd.read_csv('results/RF/years/years_only.csv')
window_results = pd.read_csv('results/RF/years/years_window.csv')
random_results = pd.read_csv('results/RF/years/years_random.csv')

# %%
# Drop all cases before 1978 because most contain too little data
only_results = only_results[only_results['year'] >= 1978]
random_results = random_results[random_results['year'] >= 1978]
window_results = window_results[window_results['year'] >= 1978]

# %%
def plot_bar(data, title):
    plt.bar(data['year'], data['accuracy'])
    plt.title(title)
    plt.xlabel('Year')
    plt.ylabel('Accuracy')
    plt.ylim(0, 1.1)

# %%
plot_bar(only_results, 'Accuracy of predicting cases of a single year')

# %%
grouped = window_results.groupby('window').mean()
plt.bar(grouped.index, grouped['accuracy'], width=3.5)
plt.title('Effects of varied number of years of training cases')
plt.xlabel('Number of years of training cases')
plt.ylabel('Accuracy')
plt.xticks(grouped.index)
plt.show()
grouped
# Out:
#           year  accuracy       MCC        F1  training_size   test_size  \
# window
# 5       2000.0  0.677742  0.187338  0.702075     210.044444  183.577778
# 10      2000.0  0.696452  0.161156  0.760210     370.622222  183.577778
# 15      2000.0  0.699849  0.152631  0.757301     479.022222  183.577778
# 20      2000.0  0.703056  0.146830  0.774617     544.488889  183.577778
# 25      2000.0  0.711999  0.147460  0.784048     579.377778  183.577778
# 30      2000.0  0.718127  0.161422  0.791947     596.888889  183.577778
# 35      2000.0  0.704556  0.141529  0.781102     604.666667  183.577778
# 40      2000.0  0.708758  0.130818  0.787807     608.400000  183.577778
# 45      2000.0  0.708755  0.128874  0.783418     610.711111  183.577778
# 50      2000.0  0.713228  0.148832  0.788958     611.822222  183.577778
# 55      2000.0  0.710869  0.133432  0.789714     612.266667  183.577778
#
#         train_distribution  test_distribution
# window
# 5                     50.0          77.729778
# 10                    50.0          77.729778
# 15                    50.0          77.729778
# 20                    50.0          77.729778
# 25                    50.0          77.729778
# 30                    50.0          77.729778
# 35                    50.0          77.729778
# 40                    50.0          77.729778
# 45                    50.0          77.729778
# 50                    50.0          77.729778
# 55                    50.0          77.729778

# %%
grouped = window_results[window_results['year']==2022]#.groupby('window').mean()
plt.bar(grouped['window'], grouped['accuracy'], width=3.5)
plt.title('Predicting cases from 2022 using varied number of years of training cases')
plt.xlabel('Number of years of training cases')
plt.ylabel('Accuracy')
plt.show()
grouped
# Out:
#      year  accuracy       MCC        F1  window  method  training_size  \
# 44   2022  0.889764  0.374329  0.939130       5  window            432
# 89   2022  0.913386  0.435320  0.952790      10  window            852
# 134  2022  0.881890  0.357518  0.934498      15  window           1342
# 179  2022  0.881890  0.357518  0.934498      20  window           1622
# 224  2022  0.881890  0.357518  0.934498      25  window           1838
# 269  2022  0.881890  0.357518  0.934498      30  window           1956
# 314  2022  0.881890  0.357518  0.934498      35  window           2006
# 359  2022  0.881890  0.357518  0.934498      40  window           2024
# 404  2022  0.881890  0.357518  0.934498      45  window           2030
# 449  2022  0.889764  0.374329  0.939130      50  window           2040
# 494  2022  0.881890  0.357518  0.934498      55  window           2048
#
#      test_size  train_distribution  test_distribution
# 44         127                50.0              92.91
# 89         127                50.0              92.91
# 134        127                50.0              92.91
# 179        127                50.0              92.91
# 224        127                50.0              92.91
# 269        127                50.0              92.91
# 314        127                50.0              92.91
# 359        127                50.0              92.91
# 404        127                50.0              92.91
# 449        127                50.0              92.91
# 494        127                50.0              92.91
