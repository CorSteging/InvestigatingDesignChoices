# %% [markdown]
# # Investigate the temporal effects of the law using the Naive Bayes Classifier

# %%
from echr import *
from nb_tfidf import *
from bert import *
import os
import re
from tqdm import tqdm
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from csv import DictWriter
from tqdm import tqdm
from joblib import Parallel, delayed

# %load_ext autoreload
# %autoreload 2

# %%
med_path = 'datasets/Medvedeva/'
json_path = 'datasets/echrod/cases.json'
part = 'facts'
article = '6'
balance = True
year = 2018
method = 'only'
best_alpha = 5

# df_complete = create_dataset(med_path, article, part)
df_complete = create_dataset(json_path, article, part)

# %%
def run_experiment(df_complete, year, method, window=None, train_size=None):
    
    # Prepare the data
    df_train, df_test = split_db(df_complete, method, year, window=window, train_size=train_size)
    df_train = balance_dataset(df_train) 
    X_train = df_train['text'].to_numpy()
    y_train = df_train['violation'].to_numpy()
    X_test = df_test['text'].to_numpy()
    y_test = df_test['violation'].to_numpy()
    
    
    if len(y_test) > 0 and len(y_train) > 0:
        # Preprocess text
        X_train_preprocessed = np.array([text_preprocessing(text) for text in X_train])
        X_test_preprocessed = np.array([text_preprocessing(text) for text in X_test])

        # Calculate TF-IDF
        tf_idf = TfidfVectorizer(ngram_range=(1, 3),
                                 binary=True,
                                 smooth_idf=False)
        X_train_tfidf = tf_idf.fit_transform(X_train_preprocessed)
        X_test_tfidf = tf_idf.transform(X_test_preprocessed)

        # Train model
        nb_model = MultinomialNB(alpha=best_alpha)
        nb_model.fit(X_train_tfidf, y_train)

        # Test model
        probs = nb_model.predict_proba(X_test_tfidf)
        preds = np.where(probs[:, 1] >= 0.5, 1, 0)
        acc, mcc, f1 = return_metrics(preds, y_test)
    else:
        print(year, len(y_train), len(y_test))
        acc, mcc, f1 = 0, 0, 0
    
    # Write the results to a csv file
    field_names = ['year', 'accuracy', 'MCC', 'F1', 'alpha',  'window', 'method', 
                   'training_size', 'test_size', 'train_distribution', 'test_distribution']
    dct = {
        'year': year,
        'accuracy': acc,
        'MCC': mcc,
        'F1': f1,
        'alpha': best_alpha,
        'method': method,
        'window': window,
        'training_size': len(df_train),
        'test_size': len(df_test),
        'train_distribution': round(df_train['violation'].mean()*100,2),
        'test_distribution': round(df_test['violation'].mean()*100,2)
         }
    
    filename = 'results/NB/years/years_'+method+'.csv'
    file_exists = os.path.isfile(filename)
    with open(filename, 'a') as f_object:
        dictwriter_object = DictWriter(f_object, fieldnames=field_names)
        if not file_exists:
            dictwriter_object.writeheader()  # file doesn't exist yet, write a header
        dictwriter_object.writerow(dct)
        f_object.close()
    return 0

# %% [markdown]
# ### Run Temporal effect Experiments

# %%
# Test set includes all cases during 'year'
all_results = Parallel(n_jobs=-1)(delayed(run_experiment)(df_complete, year, method='only') for year in tqdm(range(1978, 2023)))

# %%
# Test set includes all cases during 'year' and train on random samples of a given size
results = pd.read_csv('results/SVM/years/years_only.csv')
train_sizes = dict(zip(results['year'], results['training_size']))
all_results = Parallel(n_jobs=1)(delayed(run_experiment)(df_complete, year, method='random', train_size=train_sizes[year]) for year in tqdm(range(1978, 2023)))

# %%
# Using sliding window of X past years
all_results = Parallel(n_jobs=-1)(delayed(run_experiment)(df_complete, year, method='window', window=window) 
                                  for window in range(5, 60, 5) 
                                  for year in tqdm(range(1978, 2023)))

# %% [markdown]
# #### Analyze results

# %%
only_results = pd.read_csv('results/NB/years/years_only.csv')
window_results = pd.read_csv('results/NB/years/years_window.csv')
random_results = pd.read_csv('results/SVM/years/years_random.csv')

# %%
# Drop all cases before 1978 because most contain too little data
only_results = only_results[only_results['year'] >= 1978]
random_results = random_results[random_results['year'] >= 1978]
window_results = window_results[window_results['year'] >= 1978]

# %%
def plot_bar(data, title):
    plt.bar(data['year'], data['MCC'])
    plt.title(title)
    plt.xlabel('Year')
    plt.ylabel('MCC')

# %%
plot_bar(only_results, 'MCC of predicting cases of a single year')

# %%
grouped = window_results.groupby('window').mean()
plt.bar(grouped.index, grouped['accuracy'], width=3.5)
plt.title('Effects of varied number of years of training cases')
plt.xlabel('Number of years of training cases')
plt.ylabel('Accuracy')
plt.xticks(grouped.index)
plt.ylim(0.55, 0.7)
plt.show()
grouped
# Out:
#                year  accuracy       MCC        F1  alpha  training_size  \
# window
# 5       2000.456522  0.605126  0.165477  0.691850    5.0     215.608696
# 10      2000.511111  0.633411  0.190396  0.719442    5.0     386.444444
# 15      2000.456522  0.650854  0.185739  0.742200    5.0     497.913043
# 20      2000.456522  0.656851  0.182883  0.753935    5.0     568.260870
# 25      2000.456522  0.649279  0.165876  0.748856    5.0     606.043478
# 30      2000.456522  0.665279  0.186137  0.760909    5.0     625.478261
# 35      2000.456522  0.669426  0.210475  0.764016    5.0     633.826087
# 40      2000.456522  0.658081  0.172051  0.756766    5.0     637.782609
# 45      2000.456522  0.660385  0.184648  0.754987    5.0     640.347826
# 50      2000.456522  0.668264  0.182542  0.766136    5.0     641.478261
# 55      2000.456522  0.666337  0.192851  0.762260    5.0     642.043478
#
#          test_size  train_distribution  test_distribution
# window
# 5       187.217391                50.0          78.009565
# 10      190.111111                50.0          78.066667
# 15      187.217391                50.0          78.009565
# 20      187.217391                50.0          78.009565
# 25      187.217391                50.0          78.009565
# 30      187.217391                50.0          78.009565
# 35      187.217391                50.0          78.009565
# 40      187.217391                50.0          78.009565
# 45      187.217391                50.0          78.009565
# 50      187.217391                50.0          78.009565
# 55      187.217391                50.0          78.009565

# %%
grouped = window_results[window_results['year']==2022]#.groupby('window').mean()
plt.bar(grouped['window'], grouped['accuracy'], width=3.5)
plt.title('Predicting cases from 2022 using varied number of years of training cases')
plt.xlabel('Number of years of training cases')
plt.ylabel('Accuracy')
plt.ylim(0.55, 0.7)
plt.show()
grouped
# Out:
#      year  accuracy       MCC        F1  alpha  window  method  training_size  \
# 581  2022  0.637795  0.315984  0.757895      5       5  window            432
# 583  2022  0.637795  0.315984  0.757895      5      10  window            852
# 585  2022  0.622047  0.306050  0.744681      5      15  window           1342
# 587  2022  0.637795  0.315984  0.757895      5      20  window           1622
# 590  2022  0.629921  0.310968  0.751323      5      25  window           1838
# 591  2022  0.629921  0.310968  0.751323      5      30  window           1956
# 594  2022  0.637795  0.315984  0.757895      5      35  window           2006
# 595  2022  0.629921  0.310968  0.751323      5      40  window           2024
# 598  2022  0.629921  0.310968  0.751323      5      45  window           2030
# 600  2022  0.629921  0.310968  0.751323      5      50  window           2040
# 602  2022  0.629921  0.310968  0.751323      5      55  window           2048
#
#      test_size  train_distribution  test_distribution
# 581        127                50.0              92.91
# 583        127                50.0              92.91
# 585        127                50.0              92.91
# 587        127                50.0              92.91
# 590        127                50.0              92.91
# 591        127                50.0              92.91
# 594        127                50.0              92.91
# 595        127                50.0              92.91
# 598        127                50.0              92.91
# 600        127                50.0              92.91
# 602        127                50.0              92.91
